# %% [markdown]
# # Experiment SB (semantic bottleneck model)

# %%
# %matplotlib inline
import sys
import os

project_dir = os.path.dirname(os.getcwd())
sys.path.append(project_dir)

from utils.viz_utils import *

# %% [markdown]
# # SB

# %% [markdown]
# ## training

# %%
experiment = 'sb'
fn = os.path.join(
    project_dir, 
    'output/{0}/training/{0}_metrics.pt'.format(experiment))
show_training_losses(fn, sb = True, hierarchical = True)
show_val_results_per_epoch(fn, sb = True)
# Out:
# ########## Experiment parameters ##########
# {'adapt_loss_weights': False,
#  'batch_size': 16,
#  'debug': False,
#  'decision': 'h',
#  'epsilon_rule': 0.001,
#  'inference_batch_size': 1,
#  'input_sources': ['SI2017', 'ALTI'],
#  'interm_concepts': ['TH', 'TCD'],
#  'interm_target_sources': ['TH', 'TCD1'],
#  'interm_target_stds': [8.5075463, 37.9657575],
#  'lambda_bin': 1.0,
#  'lambda_corr': 1.0,
#  'lambda_sem': [1.0, 0.75, 0.5, 0.25],
#  'learning_schedule': [5, 5, 5, 5],
#  'lr': [1e-05, 1e-06, 1e-06, 1e-07],
#  'n_negative_samples': [0, 5, 10, 20, 40, 80, 160, 320, 320, 320],
#  'negative_sampling_schedule': [2, 2, 2, 2, 2, 2, 2, 2, 2, 2],
#  'no_user_input': True,
#  'num_epochs': 20,
#  'num_workers': 2,
#  'output_dir': 'output/sb_seed_0',
#  'padding': 64,
#  'patch_size': 128,
#  'penalize_correction': True,
#  'random_seed': 0,
#  'regression_loss': ['MSElog', 'MSE'],
#  'resume_training': False,
#  'skip_validation': False,
#  'starting_metrics_fn': None,
#  'starting_model_fn': None,
#  'target_source': 'TLM5c',
#  'thresholds': [array([1., 3.]), array([20., 60.])],
#  'train_csv_fn': 'data/csv/SI2017_ALTI_TH_TCD1_TLM5c_train_with_counts.csv',
#  'undersample_validation': 1,
#  'val_csv_fn': 'data/csv/SI2017_ALTI_TH_TCD1_TLM5c_val.csv'}
#
# ########## Loss curve(s) ##########
# ########## Validation results across training ##########
#
# Forest presence/absence
#
# classes: ['NF', 'F']
# Final task
#
# classes: ['NF', 'OF', 'CF', 'SF']
# Forest presence/absence (rule-based)
#
# classes: ['NF', 'F']
# Final task (rule-based)
#
# classes: ['NF', 'OF', 'CF', 'SF']
# Tree height
#
# classes: ['<1', '[1,3)', '>=3']
# Forest type
#
# classes: ['OF', 'CF', 'SF']
# Tree Canopy Density
#
# classes: ['<20', '[20,60)', '>=60']
# Forest type (rule-based)
#
# classes: ['OF', 'CF', 'SF']

# %% [markdown]
# ## inference

# %% [markdown]
# ### validation

# %%
experiment = 'sb'
fn = os.path.join(
    project_dir, 
    'output/{0}/training/{0}_metrics.pt'.format(experiment))
show_inference_metrics(fn, -1, sb = True, s = 5)
# Out:
# TH
#
# Plotting 111012 points
# TCD
#
# Plotting 110532 points
# Validation results (epoch -1)
#
# Final task
#
#           accuracy precision    recall  f1-score support (%)   support
#
#      NF      0.921     0.965     0.925     0.944    67.989 376697482
#
#      OF      0.941     0.117     0.280     0.165     1.934  10714019
#
#      CF      0.917     0.889     0.824     0.855    28.306 156833193
#
#      SF      0.944     0.079     0.178     0.109     1.771   9811033
#
#    mean      0.931     0.512     0.552     0.518   100.000 554055727
#
# overall      0.921     0.911     0.870     0.889   100.000 554055727
#
#
#
# Forest presence/absence
#
#           accuracy precision    recall  f1-score support (%)   support
#
#      NF      0.925     0.964     0.925     0.944    67.853 376697482
#
#       F      0.925     0.853     0.927     0.889    32.147 178465886
#
#    mean      0.925     0.909     0.926     0.916   100.000 555163368
#
# overall      0.925     0.929     0.925     0.926   100.000 555163368
#
#
#
# Forest type
#
#           accuracy precision    recall  f1-score support (%)   support
#
#      OF      0.886     0.282     0.430     0.341     6.041  21428038
#
#      CF      0.801     0.943     0.831     0.883    88.427 313666386
#
#      SF      0.849     0.171     0.397     0.239     5.532  19622066
#
#    mean      0.845     0.465     0.553     0.488   100.000 354716490
#
# overall      0.809     0.860     0.783     0.815   100.000 354716490
#
#
#
# Final task (rule-based)
#
#           accuracy precision    recall  f1-score support (%)   support
#
#      NF      0.909     0.960     0.925     0.942    67.989 376697482
#
#      OF      0.928     0.115     0.309     0.167     1.934  10714019
#
#      CF      0.816     0.875     0.453     0.597    28.306 156833193
#
#      SF      0.831     0.027     0.224     0.048     1.771   9811033
#
#    mean      0.871     0.494     0.478     0.439   100.000 554055727
#
# overall      0.881     0.903     0.767     0.814   100.000 554055727
#
#
#
# Forest presence/absence (rule-based)
#
#           accuracy precision    recall  f1-score support (%)   support
#
#      NF      0.923     0.960     0.925     0.942    67.853 376697482
#
#       F      0.923     0.853     0.918     0.884    32.147 178465886
#
#    mean      0.923     0.906     0.922     0.913   100.000 555163368
#
# overall      0.923     0.925     0.923     0.923   100.000 555163368
#
#
#
# Forest type (rule-based)
#
#           accuracy precision    recall  f1-score support (%)   support
#
#      OF      0.814     0.266     0.417     0.325     6.041  10714019
#
#      CF      0.472     0.918     0.464     0.616    88.427 156833193
#
#      SF      0.493     0.048     0.396     0.085     5.532   9811033
#
#    mean      0.593     0.411     0.425     0.342   100.000 177358245
#
# overall      0.494     0.831     0.457     0.569   100.000 177358245
#
#
#
# Tree height
#
#           accuracy precision    recall  f1-score support (%)   support
#
#      <1      0.903     0.943     0.896     0.919    59.322 329231391
#
#   [1,3)      0.884     0.238     0.324     0.275     6.635  36822245
#
#     >=3      0.937     0.907     0.924     0.915    34.044 188939002
#
#    mean      0.908     0.696     0.714     0.703   100.000 554992638
#
# overall      0.913     0.884     0.867     0.875   100.000 554992638
#
#
#
# Tree Canopy Density
#
#           accuracy precision    recall  f1-score support (%)   support
#
#     <20      0.919     0.977     0.883     0.928    55.963 309457358
#
# [20,60)      0.881     0.539     0.785     0.639    13.368  73919502
#
#    >=60      0.953     0.940     0.917     0.928    30.670 169595141
#
#    mean      0.918     0.819     0.862     0.832   100.000 552972001
#
# overall      0.925     0.907     0.880     0.889   100.000 552972001
#
#
#
# Final task
#
# IoU NF: 0.894
# IoU OF: 0.09
# IoU CF: 0.747
# IoU SF: 0.0579
# mIoU: 0.447
# Forest presence/absence
#
# IoU NF: 0.894
# IoU F: 0.8
# mIoU: 0.847
# Forest type
#
# IoU OF: 0.205
# IoU CF: 0.791
# IoU SF: 0.136
# mIoU: 0.377
# Final task (rule-based)
#
# IoU NF: 0.891
# IoU OF: 0.0911
# IoU CF: 0.426
# IoU SF: 0.0248
# mIoU: 0.358
# Forest presence/absence (rule-based)
#
# IoU NF: 0.89
# IoU F: 0.793
# mIoU: 0.842
# Forest type (rule-based)
#
# IoU OF: 0.194
# IoU CF: 0.445
# IoU SF: 0.0445
# mIoU: 0.228
# Tree height
#
# IoU <1: 0.85
# IoU [1,3): 0.159
# IoU >=3: 0.844
# mIoU: 0.618
# Tree Canopy Density
#
# IoU <20: 0.865
# IoU [20,60): 0.47
# IoU >=60: 0.866
# mIoU: 0.734

# %% [markdown]
# ### test

# %%
experiment = 'sb'
fn = os.path.join(
    project_dir, 
    'output/{0}/inference/epoch_19/test/{0}_metrics.pt'.format(experiment))
show_inference_metrics(fn, None, sb = True, s = 5, cm_ylabel='Target')
# Out:
# TH
#
# Plotting 121470 points
# TCD
#
# Plotting 120995 points
# Regression RMSE: [ 4.18169369 12.16808542]
# Regression R2 score: [0.74920442 0.89476779]
# Validation results (epoch None)
#
# Final task
#
#           accuracy precision    recall  f1-score support (%)   support
#
#      NF      0.926     0.966     0.937     0.951    73.282 444433312
#
#      OF      0.948     0.105     0.259     0.149     1.646   9982946
#
#      CF      0.924     0.887     0.795     0.838    23.541 142767011
#
#      SF      0.950     0.077     0.187     0.109     1.531   9283012
#
#    mean      0.937     0.509     0.545     0.512   100.000 606466281
#
# overall      0.927     0.920     0.881     0.899   100.000 606466281
#
#
#
# Forest presence/absence
#
#           accuracy precision    recall  f1-score support (%)   support
#
#      NF      0.930     0.966     0.937     0.951    73.154 444433312
#
#       F      0.930     0.842     0.909     0.874    26.846 163100218
#
#    mean      0.930     0.904     0.923     0.913   100.000 607533530
#
# overall      0.930     0.932     0.930     0.931   100.000 607533530
#
#
#
# Forest type
#
#           accuracy precision    recall  f1-score support (%)   support
#
#      OF      0.873     0.253     0.405     0.312     6.161  19965892
#
#      CF      0.780     0.943     0.806     0.869    88.110 285534022
#
#      SF      0.832     0.174     0.451     0.251     5.729  18566024
#
#    mean      0.828     0.457     0.554     0.477   100.000 324065938
#
# overall      0.789     0.856     0.761     0.799   100.000 324065938
#
#
#
# Final task (rule-based)
#
#           accuracy precision    recall  f1-score support (%)   support
#
#      NF      0.917     0.962     0.938     0.950    73.282 444433312
#
#      OF      0.938     0.103     0.289     0.152     1.646   9982946
#
#      CF      0.845     0.870     0.443     0.587    23.541 142767011
#
#      SF      0.861     0.025     0.192     0.043     1.531   9283012
#
#    mean      0.890     0.490     0.466     0.433   100.000 606466281
#
# overall      0.899     0.912     0.799     0.837   100.000 606466281
#
#
#
# Forest presence/absence (rule-based)
#
#           accuracy precision    recall  f1-score support (%)   support
#
#      NF      0.927     0.962     0.938     0.950    73.154 444433312
#
#       F      0.927     0.841     0.899     0.869    26.846 163100218
#
#    mean      0.927     0.902     0.918     0.909   100.000 607533530
#
# overall      0.927     0.930     0.927     0.928   100.000 607533530
#
#
#
# Forest type (rule-based)
#
#           accuracy precision    recall  f1-score support (%)   support
#
#      OF      0.795     0.238     0.398     0.298     6.161   9982946
#
#      CF      0.467     0.915     0.458     0.611    88.110 142767011
#
#      SF      0.490     0.048     0.385     0.086     5.729   9283012
#
#    mean      0.584     0.400     0.414     0.332   100.000 162032969
#
# overall      0.488     0.824     0.451     0.561   100.000 162032969
#
#
#
# Tree height
#
#           accuracy precision    recall  f1-score support (%)   support
#
#      <1      0.901     0.946     0.906     0.925    65.098 395395350
#
#   [1,3)      0.884     0.241     0.319     0.275     6.760  41058194
#
#     >=3      0.944     0.901     0.919     0.910    28.142 170927928
#
#    mean      0.910     0.696     0.715     0.703   100.000 607381472
#
# overall      0.912     0.886     0.870     0.877   100.000 607381472
#
#
#
# Tree Canopy Density
#
#           accuracy precision    recall  f1-score support (%)   support
#
#     <20      0.914     0.977     0.888     0.931    62.537 378286172
#
# [20,60)      0.880     0.505     0.771     0.611    12.194  73763343
#
#    >=60      0.957     0.934     0.907     0.920    25.269 152850576
#
#    mean      0.917     0.806     0.856     0.821   100.000 604900091
#
# overall      0.921     0.909     0.879     0.889   100.000 604900091
#
#
#
# Final task
#
# IoU NF: 0.907
# IoU OF: 0.0806
# IoU CF: 0.722
# IoU SF: 0.0576
# mIoU: 0.442
# Forest presence/absence
#
# IoU NF: 0.907
# IoU F: 0.777
# mIoU: 0.842
# Forest type
#
# IoU OF: 0.185
# IoU CF: 0.768
# IoU SF: 0.144
# mIoU: 0.365
# Final task (rule-based)
#
# IoU NF: 0.905
# IoU OF: 0.0823
# IoU CF: 0.415
# IoU SF: 0.0222
# mIoU: 0.356
# Forest presence/absence (rule-based)
#
# IoU NF: 0.904
# IoU F: 0.769
# mIoU: 0.836
# Forest type (rule-based)
#
# IoU OF: 0.175
# IoU CF: 0.44
# IoU SF: 0.045
# mIoU: 0.22
# Tree height
#
# IoU <1: 0.861
# IoU [1,3): 0.159
# IoU >=3: 0.835
# mIoU: 0.618
# Tree Canopy Density
#
# IoU <20: 0.87
# IoU [20,60): 0.439
# IoU >=60: 0.853
# mIoU: 0.721
