# %% [markdown]
# # Experiment SBcorr+ (semantic bottleneck model, low correction penalty)

# %%
# %matplotlib inline
import sys
import os

project_dir = os.path.dirname(os.getcwd())
sys.path.append(project_dir)

from utils.viz_utils import *

# %% [markdown]
# ## training

# %%
experiment = 'sb_corrp'
fn = os.path.join(
    project_dir, 
    'output/{0}/training/{0}_metrics.pt'.format(experiment))
show_training_losses(fn, sb = True, hierarchical = True)
show_val_results_per_epoch(fn, sb = True)
# Out:
# ########## Experiment parameters ##########
# {'adapt_loss_weights': False,
#  'batch_size': 16,
#  'debug': False,
#  'decision': 'h',
#  'epsilon_rule': 0.001,
#  'inference_batch_size': 1,
#  'input_sources': ['SI2017', 'ALTI'],
#  'interm_concepts': ['TH', 'TCD'],
#  'interm_target_sources': ['TH', 'TCD1'],
#  'interm_target_stds': [8.5075463, 37.9657575],
#  'lambda_bin': 1.0,
#  'lambda_corr': 1.0,
#  'lambda_sem': [1.0],
#  'learning_schedule': [5],
#  'lr': [1e-05],
#  'n_negative_samples': [0, 5, 10],
#  'negative_sampling_schedule': [2, 2, 1],
#  'no_user_input': True,
#  'num_epochs': 20,
#  'num_workers': 2,
#  'output_dir': 'output/sb_seed_0',
#  'padding': 64,
#  'patch_size': 128,
#  'penalize_correction': True,
#  'random_seed': 0,
#  'regression_loss': ['MSElog', 'MSE'],
#  'resume_training': False,
#  'skip_validation': False,
#  'starting_metrics_fn': None,
#  'starting_model_fn': None,
#  'target_source': 'TLM5c',
#  'thresholds': [array([1., 3.]), array([20., 60.])],
#  'train_csv_fn': 'data/csv/SI2017_ALTI_TH_TCD1_TLM5c_train_with_counts.csv',
#  'undersample_validation': 1,
#  'val_csv_fn': 'data/csv/SI2017_ALTI_TH_TCD1_TLM5c_val.csv'}
#
# ########## Loss curve(s) ##########
# ########## Validation results across training ##########
#
# Forest type (rule-based)
#
# classes: ['OF', 'CF', 'SF']
# Forest type
#
# classes: ['OF', 'CF', 'SF']
# Tree Canopy Density
#
# classes: ['<20', '[20,60)', '>=60']
# Forest presence/absence
#
# classes: ['NF', 'F']
# Tree height
#
# classes: ['<1', '[1,3)', '>=3']
# Final task (rule-based)
#
# classes: ['NF', 'OF', 'CF', 'SF']
# Final task
#
# classes: ['NF', 'OF', 'CF', 'SF']
# Forest presence/absence (rule-based)
#
# classes: ['NF', 'F']

# %% [markdown]
# ## inference

# %% [markdown]
# ### validation

# %%
fn = os.path.join(
    project_dir, 
    'output/{0}/training/{0}_metrics.pt'.format(experiment))
show_inference_metrics(fn, -1, sb = True, s = 5)
# Out:
# TH
#
# Plotting 111012 points
# TCD
#
# Plotting 110532 points
# Validation results (epoch -1)
#
# Final task
#
#           accuracy precision    recall  f1-score support (%)   support
#
#      NF      0.927     0.955     0.943     0.949    67.989 376697482
#
#      OF      0.949     0.115     0.215     0.150     1.934  10714019
#
#      CF      0.923     0.899     0.835     0.866    28.306 156833193
#
#      SF      0.957     0.120     0.197     0.149     1.771   9811033
#
#    mean      0.939     0.522     0.548     0.528   100.000 554055727
#
# overall      0.927     0.908     0.885     0.896   100.000 554055727
#
#
#
# Forest presence/absence
#
#           accuracy precision    recall  f1-score support (%)   support
#
#      NF      0.930     0.954     0.943     0.948    67.853 376697482
#
#       F      0.930     0.883     0.903     0.893    32.147 178465886
#
#    mean      0.930     0.918     0.923     0.920   100.000 555163368
#
# overall      0.930     0.931     0.930     0.930   100.000 555163368
#
#
#
# Forest type
#
#           accuracy precision    recall  f1-score support (%)   support
#
#      OF      0.876     0.265     0.499     0.346     6.041  21428038
#
#      CF      0.820     0.953     0.842     0.894    88.427 313666386
#
#      SF      0.883     0.260     0.493     0.340     5.532  19622066
#
#    mean      0.860     0.493     0.611     0.527   100.000 354716490
#
# overall      0.827     0.873     0.802     0.830   100.000 354716490
#
#
#
# Final task (rule-based)
#
#           accuracy precision    recall  f1-score support (%)   support
#
#      NF      0.908     0.959     0.926     0.942    67.989 376697482
#
#      OF      0.923     0.113     0.333     0.168     1.934  10714019
#
#      CF      0.816     0.883     0.447     0.594    28.306 156833193
#
#      SF      0.833     0.026     0.212     0.047     1.771   9811033
#
#    mean      0.870     0.495     0.479     0.438   100.000 554055727
#
# overall      0.881     0.905     0.766     0.813   100.000 554055727
#
#
#
# Forest presence/absence (rule-based)
#
#           accuracy precision    recall  f1-score support (%)   support
#
#      NF      0.923     0.959     0.926     0.942    67.853 376697482
#
#       F      0.923     0.854     0.916     0.884    32.147 178465886
#
#    mean      0.923     0.906     0.921     0.913   100.000 555163368
#
# overall      0.923     0.925     0.923     0.923   100.000 555163368
#
#
#
# Forest type (rule-based)
#
#           accuracy precision    recall  f1-score support (%)   support
#
#      OF      0.800     0.252     0.446     0.322     6.041  10714019
#
#      CF      0.469     0.920     0.459     0.612    88.427 156833193
#
#      SF      0.493     0.046     0.377     0.082     5.532   9811033
#
#    mean      0.587     0.406     0.427     0.339   100.000 177358245
#
# overall      0.490     0.831     0.454     0.565   100.000 177358245
#
#
#
# Tree height
#
#           accuracy precision    recall  f1-score support (%)   support
#
#      <1      0.903     0.943     0.896     0.919    59.322 329231391
#
#   [1,3)      0.884     0.239     0.328     0.276     6.635  36822245
#
#     >=3      0.937     0.909     0.922     0.916    34.044 188939002
#
#    mean      0.908     0.697     0.715     0.704   100.000 554992638
#
# overall      0.913     0.885     0.867     0.875   100.000 554992638
#
#
#
# Tree Canopy Density
#
#           accuracy precision    recall  f1-score support (%)   support
#
#     <20      0.914     0.979     0.871     0.922    55.963 309457358
#
# [20,60)      0.875     0.520     0.817     0.636    13.368  73919502
#
#    >=60      0.951     0.948     0.903     0.925    30.670 169595141
#
#    mean      0.913     0.816     0.864     0.828   100.000 552972001
#
# overall      0.920     0.908     0.874     0.885   100.000 552972001
#
#
#
# Final task
#
# IoU NF: 0.902
# IoU OF: 0.081
# IoU CF: 0.763
# IoU SF: 0.0806
# mIoU: 0.457
# Forest presence/absence
#
# IoU NF: 0.902
# IoU F: 0.806
# mIoU: 0.854
# Forest type
#
# IoU OF: 0.209
# IoU CF: 0.808
# IoU SF: 0.205
# mIoU: 0.408
# Final task (rule-based)
#
# IoU NF: 0.891
# IoU OF: 0.092
# IoU CF: 0.422
# IoU SF: 0.0238
# mIoU: 0.357
# Forest presence/absence (rule-based)
#
# IoU NF: 0.89
# IoU F: 0.792
# mIoU: 0.841
# Forest type (rule-based)
#
# IoU OF: 0.192
# IoU CF: 0.441
# IoU SF: 0.0429
# mIoU: 0.225
# Tree height
#
# IoU <1: 0.851
# IoU [1,3): 0.16
# IoU >=3: 0.844
# mIoU: 0.618
# Tree Canopy Density
#
# IoU <20: 0.856
# IoU [20,60): 0.466
# IoU >=60: 0.861
# mIoU: 0.727

# %% [markdown]
# ### test

# %%
fn = os.path.join(
    project_dir, 
    'output/{0}/inference/epoch_19/test/{0}_metrics.pt'.format(experiment))
show_inference_metrics(fn, None, sb = True, s = 5, cm_ylabel='Target')
# Out:
# TH
#
# Plotting 121470 points
# TCD
#
# Plotting 120995 points
# Regression RMSE: [ 4.16394579 12.94616337]
# Regression R2 score: [0.75132875 0.88087954]
# Validation results (epoch None)
#
# Final task
#
#           accuracy precision    recall  f1-score support (%)   support
#
#      NF      0.932     0.958     0.953     0.955    73.282 444433312
#
#      OF      0.957     0.104     0.193     0.135     1.646   9982946
#
#      CF      0.930     0.896     0.806     0.849    23.541 142767011
#
#      SF      0.959     0.108     0.203     0.141     1.531   9283012
#
#    mean      0.944     0.516     0.539     0.520   100.000 606466281
#
# overall      0.932     0.916     0.894     0.904   100.000 606466281
#
#
#
# Forest presence/absence
#
#           accuracy precision    recall  f1-score support (%)   support
#
#      NF      0.934     0.957     0.953     0.955    73.154 444433312
#
#       F      0.934     0.873     0.883     0.878    26.846 163100218
#
#    mean      0.934     0.915     0.918     0.917   100.000 607533530
#
# overall      0.934     0.935     0.934     0.934   100.000 607533530
#
#
#
# Forest type
#
#           accuracy precision    recall  f1-score support (%)   support
#
#      OF      0.865     0.244     0.463     0.320     6.161  19965892
#
#      CF      0.797     0.954     0.815     0.879    88.110 285534022
#
#      SF      0.863     0.245     0.556     0.340     5.729  18566024
#
#    mean      0.842     0.481     0.611     0.513   100.000 324065938
#
# overall      0.805     0.869     0.778     0.814   100.000 324065938
#
#
#
# Final task (rule-based)
#
#           accuracy precision    recall  f1-score support (%)   support
#
#      NF      0.917     0.962     0.938     0.950    73.282 444433312
#
#      OF      0.934     0.102     0.309     0.154     1.646   9982946
#
#      CF      0.845     0.877     0.438     0.584    23.541 142767011
#
#      SF      0.863     0.024     0.186     0.043     1.531   9283012
#
#    mean      0.890     0.491     0.468     0.433   100.000 606466281
#
# overall      0.899     0.913     0.799     0.837   100.000 606466281
#
#
#
# Forest presence/absence (rule-based)
#
#           accuracy precision    recall  f1-score support (%)   support
#
#      NF      0.927     0.961     0.938     0.950    73.154 444433312
#
#       F      0.927     0.842     0.897     0.869    26.846 163100218
#
#    mean      0.927     0.902     0.918     0.909   100.000 607533530
#
# overall      0.927     0.929     0.927     0.928   100.000 607533530
#
#
#
# Forest type (rule-based)
#
#           accuracy precision    recall  f1-score support (%)   support
#
#      OF      0.784     0.229     0.423     0.297     6.161   9982946
#
#      CF      0.464     0.916     0.454     0.607    88.110 142767011
#
#      SF      0.491     0.047     0.371     0.084     5.729   9283012
#
#    mean      0.580     0.397     0.416     0.329   100.000 162032969
#
# overall      0.485     0.824     0.448     0.558   100.000 162032969
#
#
#
# Tree height
#
#           accuracy precision    recall  f1-score support (%)   support
#
#      <1      0.901     0.946     0.906     0.925    65.098 395395350
#
#   [1,3)      0.884     0.241     0.324     0.276     6.760  41058194
#
#     >=3      0.945     0.903     0.918     0.910    28.142 170927928
#
#    mean      0.910     0.697     0.716     0.704   100.000 607381472
#
# overall      0.912     0.886     0.870     0.877   100.000 607381472
#
#
#
# Tree Canopy Density
#
#           accuracy precision    recall  f1-score support (%)   support
#
#     <20      0.907     0.980     0.875     0.925    62.537 378286172
#
# [20,60)      0.872     0.486     0.801     0.605    12.194  73763343
#
#    >=60      0.956     0.942     0.895     0.918    25.269 152850576
#
#    mean      0.912     0.802     0.857     0.816   100.000 604900091
#
# overall      0.915     0.910     0.871     0.884   100.000 604900091
#
#
#
# Final task
#
# IoU NF: 0.915
# IoU OF: 0.0726
# IoU CF: 0.737
# IoU SF: 0.0756
# mIoU: 0.45
# Forest presence/absence
#
# IoU NF: 0.914
# IoU F: 0.783
# mIoU: 0.848
# Forest type
#
# IoU OF: 0.19
# IoU CF: 0.784
# IoU SF: 0.205
# mIoU: 0.393
# Final task (rule-based)
#
# IoU NF: 0.905
# IoU OF: 0.0832
# IoU CF: 0.413
# IoU SF: 0.0219
# mIoU: 0.356
# Forest presence/absence (rule-based)
#
# IoU NF: 0.904
# IoU F: 0.768
# mIoU: 0.836
# Forest type (rule-based)
#
# IoU OF: 0.174
# IoU CF: 0.436
# IoU SF: 0.0438
# mIoU: 0.218
# Tree height
#
# IoU <1: 0.861
# IoU [1,3): 0.16
# IoU >=3: 0.835
# mIoU: 0.619
# Tree Canopy Density
#
# IoU <20: 0.86
# IoU [20,60): 0.433
# IoU >=60: 0.848
# mIoU: 0.714
