# %% [markdown]
# # Experiments with black-box model

# %%
# %matplotlib inline
import sys
import os

project_dir = os.path.dirname(os.getcwd())
sys.path.append(project_dir)

from utils.viz_utils import *

# %% [markdown]
# # No class hierarchy
# Single task with NF, OF, CF, SF classes

# %% [markdown]
# ## training

# %%
fn = os.path.join(project_dir, 'output/bb_flat_seed_0/training/bb_flat_seed_0_metrics.pt')
show_detailed_training_results(fn, sb = False)
show_training_losses(fn, sb = False, hierarchical = False)
# Out:
# seg_2
# ['NF', 'F']
# seg
# ['NF', 'OF', 'CF', 'SF']
# {'input_sources': ['SI2017', 'ALTI'], 'target_source': 'TLM5c', 'interm_target_sources': [], 'train_csv_fn': 'data/csv/SI2017_ALTI_TLM5c_train_with_counts.csv', 'val_csv_fn': 'data/csv/SI2017_ALTI_TLM5c_val.csv', 'output_dir': 'output/bb_flat_seed_0', 'batch_size': 16, 'patch_size': 128, 'inference_batch_size': 1, 'num_epochs': 20, 'lr': [1e-05, 1e-06, 1e-06, 1e-07], 'learning_schedule': [5, 5, 5, 5], 'n_negative_samples': [0, 5, 10, 20, 40, 80, 160, 320, 320, 320], 'negative_sampling_schedule': [2, 2, 2, 2, 2, 2, 2, 2, 2, 2], 'decision': 'f', 'num_workers': 2, 'skip_validation': False, 'undersample_validation': 1, 'padding': 64, 'resume_training': False, 'starting_model_fn': None, 'starting_metrics_fn': None, 'no_user_input': True, 'debug': False, 'adapt_loss_weights': False, 'regression_loss': None, 'penalize_correction': False, 'lambda_bin': 1.0, 'lambda_sem': [0.0], 'lambda_corr': 0.0, 'epsilon_rule': None, 'random_seed': 0}

# %% [markdown]
# ## inference
# ### validation

# %%
fn = '../output/bb_flat_seed_0/training/bb_flat_seed_0_metrics.pt'
show_model_metrics(fn, -1, sb = False, s = 5)
# Out:
# Validation results (epoch -1)
# seg
#           accuracy precision    recall  f1-score support (%)   support
#
#      NF      0.913     0.991     0.886     0.936    67.989 376697482
#
#      OF      0.930     0.184     0.690     0.291     1.934  10714019
#
#      CF      0.921     0.885     0.845     0.865    28.306 156833193
#
#      SF      0.956     0.275     0.770     0.405     1.771   9811033
#
#    mean      0.930     0.584     0.798     0.624   100.000 554055727
#
# overall      0.916     0.933     0.869     0.894   100.000 554055727
#
#
# seg_2
#           accuracy precision    recall  f1-score support (%)   support
#
#      NF      0.889     0.996     0.840     0.911    67.853 376697482
#
#       F      0.889     0.746     0.993     0.852    32.147 178465886
#
#    mean      0.889     0.871     0.916     0.881   100.000 555163368
#
# overall      0.889     0.915     0.889     0.892   100.000 555163368
#
#
# seg
# IoU NF: 0.8789306282997131
# IoU OF: 0.1702835112810135
# IoU CF: 0.7616727948188782
# IoU SF: 0.25398027896881104
# mIoU: 0.516216803342104
# seg_2
# IoU NF: 0.8367511630058289
# IoU F: 0.7416350841522217
# mIoU: 0.7891931235790253

# %% [markdown]
# ### test

# %%
fn = os.path.join(project_dir, 'output/bb_flat_seed_0/inference/epoch_19/test/bb_flat_seed_0_metrics.pt')
show_model_metrics(fn, None, sb = False, s = 5)
# Out:
# Validation results (epoch None)
# seg
#           accuracy precision    recall  f1-score support (%)   support
#
#      NF      0.921     0.990     0.906     0.946    73.282 444433312
#
#      OF      0.950     0.206     0.656     0.314     1.646   9982946
#
#      CF      0.934     0.879     0.850     0.864    23.541 142767011
#
#      SF      0.957     0.254     0.819     0.388     1.531   9283012
#
#    mean      0.940     0.582     0.808     0.628   100.000 606466281
#
# overall      0.925     0.940     0.887     0.908   100.000 606466281
#
#
# seg_2
#           accuracy precision    recall  f1-score support (%)   support
#
#      NF      0.894     0.995     0.860     0.923    73.154 444433312
#
#       F      0.894     0.721     0.988     0.834    26.846 163100218
#
#    mean      0.894     0.858     0.924     0.878   100.000 607533530
#
# overall      0.894     0.922     0.894     0.899   100.000 607533530
#
#
# seg
# IoU NF: 0.8975964784622192
# IoU OF: 0.18624545633792877
# IoU CF: 0.7609170079231262
# IoU SF: 0.24031086266040802
# mIoU: 0.5212674513459206
# seg_2
# IoU NF: 0.8561857342720032
# IoU F: 0.715172290802002
# mIoU: 0.7856790125370026

# %% [markdown]
# # Weighted forest presence/absence loss
# Binary loss with class-specific weights corresponding to the full set of classes

# %% [markdown]
# ## training

# %%
fn = os.path.join(project_dir, 'output/bb_weighted_bin_loss_seed_0/training/bb_weighted_bin_loss_seed_0_metrics.pt')
show_detailed_training_results(fn, sb = False)
show_training_losses(fn, sb = False, hierarchical = True)
# Out:
# seg_2
# ['NF', 'F']
# seg_1
# ['OF', 'CF', 'SF']
# seg
# ['NF', 'OF', 'CF', 'SF']
# {'input_sources': ['SI2017', 'ALTI'], 'target_source': 'TLM5c', 'interm_target_sources': [], 'train_csv_fn': 'data/csv/SI2017_ALTI_TLM5c_train_with_counts.csv', 'val_csv_fn': 'data/csv/SI2017_ALTI_TLM5c_val.csv', 'output_dir': 'output/bb_weighted_bin_loss_seed_0', 'batch_size': 16, 'patch_size': 128, 'inference_batch_size': 1, 'num_epochs': 20, 'lr': [1e-05, 1e-06, 1e-06, 1e-07], 'learning_schedule': [5, 5, 5, 5], 'n_negative_samples': [0, 5, 10, 20, 40, 80, 160, 320, 320, 320], 'negative_sampling_schedule': [2, 2, 2, 2, 2, 2, 2, 2, 2, 2], 'decision': 'h', 'num_workers': 2, 'skip_validation': False, 'undersample_validation': 1, 'padding': 64, 'resume_training': False, 'starting_model_fn': None, 'starting_metrics_fn': None, 'no_user_input': True, 'debug': False, 'adapt_loss_weights': False, 'regression_loss': None, 'penalize_correction': False, 'lambda_bin': 1.0, 'lambda_sem': [0.0], 'lambda_corr': 0.0, 'epsilon_rule': None, 'random_seed': 0}

# %% [markdown]
# ## inference
# ### validation

# %%
fn = '../output/bb_weighted_bin_loss_seed_0/training/bb_weighted_bin_loss_seed_0_metrics.pt'
show_model_metrics(fn, -1, sb = False, s = 5)
# Out:
# Validation results (epoch -1)
# seg
#           accuracy precision    recall  f1-score support (%)   support
#
#      NF      0.856     0.998     0.799     0.887    67.989 376697482
#
#      OF      0.909     0.148     0.686     0.243     1.934  10714019
#
#      CF      0.908     0.827     0.893     0.859    28.306 156833193
#
#      SF      0.940     0.215     0.731     0.332     1.771   9811033
#
#    mean      0.903     0.547     0.777     0.580   100.000 554055727
#
# overall      0.873     0.919     0.822     0.857   100.000 554055727
#
#
# seg_2
#           accuracy precision    recall  f1-score support (%)   support
#
#      NF      0.862     0.997     0.799     0.887    67.853 376697482
#
#       F      0.862     0.701     0.996     0.823    32.147 178465886
#
#    mean      0.862     0.849     0.897     0.855   100.000 555163368
#
# overall      0.862     0.902     0.862     0.866   100.000 555163368
#
#
# seg_1
#           accuracy precision    recall  f1-score support (%)   support
#
#      OF      0.905     0.364     0.695     0.478     6.041  10714019
#
#      CF      0.880     0.969     0.894     0.930    88.427 156833193
#
#      SF      0.954     0.595     0.741     0.660     5.532   9811033
#
#    mean      0.913     0.643     0.777     0.689   100.000 177358245
#
# overall      0.886     0.912     0.874     0.888   100.000 177358245
#
#
# seg
# IoU NF: 0.7970006465911865
# IoU OF: 0.13818956911563873
# IoU CF: 0.7522180080413818
# IoU SF: 0.19898682832717896
# mIoU: 0.4715987630188465
# seg_2
# IoU NF: 0.7969149351119995
# IoU F: 0.6985997557640076
# mIoU: 0.7477573454380035
# seg_1
# IoU OF: 0.313815712928772
# IoU CF: 0.8693715929985046
# IoU SF: 0.4928707182407379
# mIoU: 0.5586860080560049

# %% [markdown]
# ### test

# %%
fn = os.path.join(project_dir, 'output/bb_weighted_bin_loss_seed_0/inference/epoch_19/test/bb_weighted_bin_loss_seed_0_metrics.pt')
show_model_metrics(fn, None, sb = False, s = 5)
# Out:
# Validation results (epoch None)
# seg
#           accuracy precision    recall  f1-score support (%)   support
#
#      NF      0.862     0.996     0.820     0.900    73.282 444433312
#
#      OF      0.925     0.147     0.655     0.240     1.646   9982946
#
#      CF      0.920     0.814     0.897     0.854    23.541 142767011
#
#      SF      0.939     0.196     0.817     0.316     1.531   9283012
#
#    mean      0.911     0.538     0.797     0.577   100.000 606466281
#
# overall      0.878     0.927     0.836     0.869   100.000 606466281
#
#
# seg_2
#           accuracy precision    recall  f1-score support (%)   support
#
#      NF      0.866     0.996     0.820     0.900    73.154 444433312
#
#       F      0.866     0.669     0.990     0.799    26.846 163100218
#
#    mean      0.866     0.833     0.905     0.849   100.000 607533530
#
# overall      0.866     0.908     0.866     0.873   100.000 607533530
#
#
# seg_1
#           accuracy precision    recall  f1-score support (%)   support
#
#      OF      0.919     0.419     0.668     0.515     6.161   9982946
#
#      CF      0.889     0.972     0.901     0.935    88.110 142767011
#
#      SF      0.951     0.571     0.848     0.682     5.729   9283012
#
#    mean      0.920     0.654     0.805     0.711   100.000 162032969
#
# overall      0.894     0.915     0.884     0.895   100.000 162032969
#
#
# seg
# IoU NF: 0.8175969123840332
# IoU OF: 0.13649773597717285
# IoU CF: 0.7448046207427979
# IoU SF: 0.18792523443698883
# mIoU: 0.4717061258852482
# seg_2
# IoU NF: 0.817511260509491
# IoU F: 0.6649730801582336
# mIoU: 0.7412421703338623
# seg_1
# IoU OF: 0.3467447757720947
# IoU CF: 0.8780586123466492
# IoU SF: 0.5176904201507568
# mIoU: 0.5808312694231669

# %% [markdown]
# # Input SI, w/o ALTI
# ## training

# %%
fn = os.path.join(project_dir, 'output/bb_wo_alti_seed_0/training/bb_wo_alti_seed_0_metrics.pt')
show_detailed_training_results(fn, sb = False)
show_training_losses(fn, sb = False, hierarchical = True)
# Out:
# seg_2
# ['NF', 'F']
# seg_1
# ['OF', 'CF', 'SF']
# seg
# ['NF', 'OF', 'CF', 'SF']
# {'input_sources': ['SI2017'], 'target_source': 'TLM5c', 'interm_target_sources': [], 'train_csv_fn': 'data/csv/SI2017_TLM5c_train_with_counts.csv', 'val_csv_fn': 'data/csv/SI2017_TLM5c_val.csv', 'output_dir': 'output/bb_wo_alti_seed_0', 'batch_size': 16, 'patch_size': 128, 'inference_batch_size': 1, 'num_epochs': 20, 'lr': [1e-05, 1e-06, 1e-06, 1e-07], 'learning_schedule': [5, 5, 5, 5], 'n_negative_samples': [0, 5, 10, 20, 40, 80, 160, 320, 320, 320], 'negative_sampling_schedule': [2, 2, 2, 2, 2, 2, 2, 2, 2, 2], 'decision': 'h', 'num_workers': 2, 'skip_validation': False, 'undersample_validation': 1, 'padding': 64, 'resume_training': False, 'starting_model_fn': None, 'starting_metrics_fn': None, 'no_user_input': False, 'debug': False, 'adapt_loss_weights': False, 'regression_loss': None, 'penalize_correction': False, 'lambda_bin': 1.0, 'lambda_sem': [0.0], 'lambda_corr': 0.0, 'epsilon_rule': None, 'random_seed': 0}

# %% [markdown]
# ## inference
# ### validation

# %%
fn = '../output/bb_wo_alti_seed_0/training/bb_wo_alti_seed_0_metrics.pt'
show_model_metrics(fn, -1, sb = False, s = 5)
# Out:
# Validation results (epoch -1)
# seg
#           accuracy precision    recall  f1-score support (%)   support
#
#      NF      0.912     0.983     0.891     0.935    67.989 376712373
#
#      OF      0.947     0.191     0.484     0.274     1.934  10714097
#
#      CF      0.929     0.868     0.898     0.883    28.306 156837683
#
#      SF      0.957     0.238     0.565     0.335     1.771   9811033
#
#    mean      0.936     0.570     0.710     0.607   100.000 554075186
#
# overall      0.918     0.922     0.879     0.897   100.000 554075186
#
#
# seg_2
#           accuracy precision    recall  f1-score support (%)   support
#
#      NF      0.915     0.982     0.891     0.934    67.854 376712373
#
#       F      0.915     0.808     0.966     0.880    32.146 178470589
#
#    mean      0.915     0.895     0.929     0.907   100.000 555182962
#
# overall      0.915     0.926     0.915     0.917   100.000 555182962
#
#
# seg_1
#           accuracy precision    recall  f1-score support (%)   support
#
#      OF      0.922     0.421     0.597     0.494     6.041  10714097
#
#      CF      0.879     0.962     0.900     0.930    88.428 156837683
#
#      SF      0.934     0.465     0.727     0.567     5.532   9811033
#
#    mean      0.912     0.616     0.741     0.663   100.000 177362813
#
# overall      0.885     0.902     0.872     0.883   100.000 177362813
#
#
# seg
# IoU NF: 0.8773146867752075
# IoU OF: 0.1590651273727417
# IoU CF: 0.790477454662323
# IoU SF: 0.20097121596336365
# mIoU: 0.506957121193409
# seg_2
# IoU NF: 0.8769422173500061
# IoU F: 0.7854827046394348
# mIoU: 0.8312124609947205
# seg_1
# IoU OF: 0.32766401767730713
# IoU CF: 0.8690502643585205
# IoU SF: 0.39557555317878723
# mIoU: 0.5307632784048716

# %% [markdown]
# ### test

# %%
experiment = 'bb_wo_alti_seed_0'
fn = os.path.join(project_dir, 'output/{}/inference/epoch_19/test/{}_metrics.pt'.format(experiment, experiment))
show_model_metrics(fn, None, sb = False, s = 5)
# Out:
# Validation results (epoch None)
# seg
#           accuracy precision    recall  f1-score support (%)   support
#
#      NF      0.920     0.982     0.910     0.945    73.282 444448020
#
#      OF      0.958     0.198     0.451     0.275     1.646   9983450
#
#      CF      0.936     0.861     0.882     0.872    23.541 142774413
#
#      SF      0.959     0.227     0.626     0.333     1.531   9283012
#
#    mean      0.943     0.567     0.717     0.606   100.000 606488895
#
# overall      0.925     0.929     0.892     0.907   100.000 606488895
#
#
# seg_2
#           accuracy precision    recall  f1-score support (%)   support
#
#      NF      0.922     0.982     0.910     0.945    73.153 444448020
#
#       F      0.922     0.796     0.954     0.868    26.847 163108124
#
#    mean      0.922     0.889     0.932     0.906   100.000 607556144
#
# overall      0.922     0.932     0.922     0.924   100.000 607556144
#
#
# seg_1
#           accuracy precision    recall  f1-score support (%)   support
#
#      OF      0.924     0.439     0.557     0.491     6.161   9983450
#
#      CF      0.868     0.963     0.886     0.923    88.110 142774413
#
#      SF      0.923     0.432     0.834     0.569     5.729   9283012
#
#    mean      0.905     0.611     0.759     0.661   100.000 162040875
#
# overall      0.875     0.900     0.863     0.876   100.000 162040875
#
#
# seg
# IoU NF: 0.8957539796829224
# IoU OF: 0.1592913717031479
# IoU CF: 0.7725260257720947
# IoU SF: 0.19982695579528809
# mIoU: 0.5068495832383633
# seg_2
# IoU NF: 0.8953642845153809
# IoU F: 0.7670069336891174
# mIoU: 0.8311856091022491
# seg_1
# IoU OF: 0.3253111243247986
# IoU CF: 0.856586754322052
# IoU SF: 0.39810293912887573
# mIoU: 0.5266669392585754

# %% [markdown]
# # Inputs SI + ALTI
# ## training

# %%
fn = os.path.join(project_dir, 'output/bb_seed_0/training/bb_seed_0_metrics.pt')
show_detailed_training_results(fn, sb = False)
show_training_losses(fn, sb = False, hierarchical = True)
# Out:
# seg_2
# ['NF', 'F']
# seg_1
# ['OF', 'CF', 'SF']
# seg
# ['NF', 'OF', 'CF', 'SF']
# {'input_sources': ['SI2017', 'ALTI'], 'target_source': 'TLM5c', 'interm_target_sources': [], 'train_csv_fn': 'data/csv/SI2017_ALTI_TLM5c_train_with_counts.csv', 'val_csv_fn': 'data/csv/SI2017_ALTI_TLM5c_val.csv', 'output_dir': 'output/bb_seed_0', 'batch_size': 16, 'patch_size': 128, 'inference_batch_size': 1, 'num_epochs': 20, 'lr': [1e-05], 'learning_schedule': [11], 'n_negative_samples': [0], 'negative_sampling_schedule': [11], 'decision': 'h', 'num_workers': 2, 'skip_validation': False, 'undersample_validation': 1, 'padding': 64, 'resume_training': False, 'starting_model_fn': None, 'starting_metrics_fn': None, 'no_user_input': True, 'debug': False, 'adapt_loss_weights': False, 'regression_loss': None, 'penalize_correction': False, 'lambda_bin': 1.0, 'lambda_sem': [0.0], 'lambda_corr': 0.0, 'epsilon_rule': None, 'random_seed': 0}

# %% [markdown]
# ## inference

# %% [markdown]
# ### validation

# %%
fn = '../output/bb_seed_0/training/bb_seed_0_metrics.pt'
show_model_metrics(fn, -1, sb = False, s = 5)
# Out:
# Validation results (epoch -1)
# seg
#           accuracy precision    recall  f1-score support (%)   support
#
#      NF      0.927     0.981     0.915     0.947    67.989 376697482
#
#      OF      0.952     0.222     0.521     0.311     1.934  10714019
#
#      CF      0.929     0.874     0.888     0.881    28.306 156833193
#
#      SF      0.968     0.320     0.593     0.415     1.771   9811033
#
#    mean      0.944     0.599     0.729     0.639   100.000 554055727
#
# overall      0.929     0.924     0.894     0.906   100.000 554055727
#
#
# seg_2
#           accuracy precision    recall  f1-score support (%)   support
#
#      NF      0.930     0.980     0.915     0.947    67.853 376697482
#
#       F      0.930     0.843     0.962     0.898    32.147 178465886
#
#    mean      0.930     0.912     0.938     0.922   100.000 555163368
#
# overall      0.930     0.936     0.930     0.931   100.000 555163368
#
#
# seg_1
#           accuracy precision    recall  f1-score support (%)   support
#
#      OF      0.912     0.388     0.669     0.491     6.041  10714019
#
#      CF      0.879     0.970     0.892     0.929    88.427 156833193
#
#      SF      0.944     0.520     0.779     0.624     5.532   9811033
#
#    mean      0.912     0.626     0.780     0.681   100.000 177358245
#
# overall      0.884     0.910     0.872     0.886   100.000 177358245
#
#
# seg
# IoU NF: 0.8990066051483154
# IoU OF: 0.18431061506271362
# IoU CF: 0.7867283821105957
# IoU SF: 0.26213565468788147
# mIoU: 0.5330453142523766
# seg_2
# IoU NF: 0.8985325694084167
# IoU F: 0.8151325583457947
# mIoU: 0.8568325638771057
# seg_1
# IoU OF: 0.3257352411746979
# IoU CF: 0.8676409125328064
# IoU SF: 0.45332056283950806
# mIoU: 0.5488989055156708

# %% [markdown]
# ### test (old)

# %%
fn = os.path.join(project_dir, 'output/bb_seed_0/inference/epoch_19/test/bb_seed_0_metrics.pt')
show_model_metrics(fn, None, sb = False, s = 5)
# Out:
# Validation results (epoch None)
# seg
#           accuracy precision    recall  f1-score support (%)   support
#
#      NF      0.933     0.982     0.929     0.954    73.282 444433312
#
#      OF      0.965     0.245     0.482     0.325     1.646   9982946
#
#      CF      0.940     0.867     0.889     0.878    23.541 142767011
#
#      SF      0.969     0.294     0.638     0.402     1.531   9283012
#
#    mean      0.952     0.597     0.734     0.640   100.000 606466281
#
# overall      0.936     0.932     0.907     0.918   100.000 606466281
#
#
# seg_2
#           accuracy precision    recall  f1-score support (%)   support
#
#      NF      0.935     0.981     0.929     0.954    73.154 444433312
#
#       F      0.935     0.830     0.952     0.887    26.846 163100218
#
#    mean      0.935     0.906     0.940     0.921   100.000 607533530
#
# overall      0.935     0.941     0.935     0.936   100.000 607533530
#
#
# seg_1
#           accuracy precision    recall  f1-score support (%)   support
#
#      OF      0.923     0.436     0.621     0.512     6.161   9982946
#
#      CF      0.883     0.970     0.895     0.931    88.110 142767011
#
#      SF      0.939     0.502     0.867     0.636     5.729   9283012
#
#    mean      0.915     0.636     0.794     0.693   100.000 162032969
#
# overall      0.888     0.910     0.877     0.888   100.000 162032969
#
#
# seg
# IoU NF: 0.9129583239555359
# IoU OF: 0.19374202191829681
# IoU CF: 0.7817755341529846
# IoU SF: 0.2519184947013855
# mIoU: 0.5350985936820507
# seg_2
# IoU NF: 0.9125362038612366
# IoU F: 0.797010064125061
# mIoU: 0.8547731339931488
# seg_1
# IoU OF: 0.34410619735717773
# IoU CF: 0.8712819814682007
# IoU SF: 0.4659751355648041
# mIoU: 0.5604544381300608

# %% [markdown]
# ### test

# %%
fn = os.path.join(project_dir, 'output/bb_seed_0/inference/epoch_19/test/bb_seed_0_metrics.pt')
show_model_metrics(fn, None, sb = False, s = 5)
# Out:
# Validation results (epoch None)
# seg
#           accuracy precision    recall  f1-score support (%)   support
#
#      NF      0.933     0.982     0.929     0.954    73.282 444433312
#
#      OF      0.965     0.245     0.482     0.325     1.646   9982946
#
#      CF      0.940     0.867     0.889     0.878    23.541 142767011
#
#      SF      0.969     0.294     0.638     0.402     1.531   9283012
#
#    mean      0.952     0.597     0.734     0.640   100.000 606466281
#
# overall      0.936     0.932     0.907     0.918   100.000 606466281
#
#
# seg_2
#           accuracy precision    recall  f1-score support (%)   support
#
#      NF      0.935     0.981     0.929     0.954    73.154 444433312
#
#       F      0.935     0.830     0.952     0.887    26.846 163100218
#
#    mean      0.935     0.906     0.940     0.921   100.000 607533530
#
# overall      0.935     0.941     0.935     0.936   100.000 607533530
#
#
# seg_1
#           accuracy precision    recall  f1-score support (%)   support
#
#      OF      0.923     0.436     0.621     0.512     6.161   9982946
#
#      CF      0.883     0.970     0.895     0.931    88.110 142767011
#
#      SF      0.939     0.502     0.867     0.636     5.729   9283012
#
#    mean      0.915     0.636     0.794     0.693   100.000 162032969
#
# overall      0.888     0.910     0.877     0.888   100.000 162032969
#
#
# seg
# IoU NF: 0.9129583239555359
# IoU OF: 0.19374202191829681
# IoU CF: 0.7817755341529846
# IoU SF: 0.2519184947013855
# mIoU: 0.5350985936820507
# seg_2
# IoU NF: 0.9125362038612366
# IoU F: 0.797010064125061
# mIoU: 0.8547731339931488
# seg_1
# IoU OF: 0.34410619735717773
# IoU CF: 0.8712819814682007
# IoU SF: 0.4659751355648041
# mIoU: 0.5604544381300608
