# %% [markdown]
# # Evaluate intermediate concept targets

# %%
# %matplotlib inline
import sys
import os
sys.path.append(os.path.dirname(os.path.dirname(os.getcwd())))
import torch

from utils.viz_utils import *

# %%
class_names = (['NF', 'OF', 'CF', 'SF'], ['NF', 'F'], ['OF', 'CF', 'SF'])

def display_results(metrics_fn):
    d = torch.load(metrics_fn)
    cms = d['cms']
    reports = d['reports']
    for key, cn in zip(cms.keys(), class_names):
        print(cn)
        display_norm_cm(cms[key], class_names=cn)
        print_report(reports[key])

# %% [markdown]
# ## Validation

# %%
metrics_fn = os.path.join(os.getcwd(), 'output/rules_on_regr_labels_TH_TCD1/metrics.pt')
display_results(metrics_fn)
# Out:
# ['NF', 'OF', 'CF', 'SF']
#           accuracy precision    recall  f1-score support (%)   support
#
#      NF       0.92      0.96      0.93      0.94     68.35 396119387
#
#      OF       0.94      0.12      0.30      0.17      1.90  11024403
#
#      CF       0.95      0.95      0.88      0.92     28.01 162319093
#
#      SF       0.97      0.39      0.62      0.48      1.74  10089306
#
#    mean       0.95      0.60      0.68      0.63    100.00 579552189
#
# overall       0.93      0.93      0.90      0.91    100.00 579552189
#
#
# ['NF', 'F']
#           accuracy precision    recall  f1-score support (%)   support
#
#      NF       0.91      0.96      0.91      0.93     68.46 405964969
#
#       F       0.91      0.82      0.91      0.87     31.54 187035031
#
#    mean       0.91      0.89      0.91      0.90    100.00 593000000
#
# overall       0.91      0.92      0.91      0.91    100.00 593000000
#
#
# ['OF', 'CF', 'SF']
#           accuracy precision    recall  f1-score support (%)   support
#
#      OF       0.92      0.27      0.47      0.34      4.21   7142084
#
#      CF       0.92      0.99      0.93      0.96     91.40 155216863
#
#      SF       0.95      0.51      0.84      0.63      4.40   7471134
#
#    mean       0.93      0.59      0.74      0.64    100.00 169830081
#
# overall       0.92      0.94      0.90      0.92    100.00 169830081

# %% [markdown]
# ## Test

# %%
metrics_fn = os.path.join(os.getcwd(), 'output/rules_on_regr_labels_TH_TCD1/test/metrics.pt')
display_results(metrics_fn)
# Out:
# ['NF', 'OF', 'CF', 'SF']
#           accuracy precision    recall  f1-score support (%)   support
#
#      NF       0.92      0.96      0.94      0.95     74.47 484800696
#
#      OF       0.95      0.10      0.28      0.15      1.57  10201105
#
#      CF       0.95      0.93      0.86      0.90     22.49 146391059
#
#      SF       0.97      0.30      0.51      0.38      1.48   9609568
#
#    mean       0.95      0.57      0.65      0.59    100.00 651002428
#
# overall       0.93      0.93      0.90      0.92    100.00 651002428
#
#
# ['NF', 'F']
#           accuracy precision    recall  f1-score support (%)   support
#
#      NF       0.90      0.96      0.90      0.93     74.82 503547090
#
#       F       0.90      0.75      0.89      0.82     25.18 169452910
#
#    mean       0.90      0.86      0.90      0.87    100.00 673000000
#
# overall       0.90      0.91      0.90      0.90    100.00 673000000
#
#
# ['OF', 'CF', 'SF']
#           accuracy precision    recall  f1-score support (%)   support
#
#      OF       0.91      0.24      0.43      0.31      4.35   6552575
#
#      CF       0.91      0.99      0.91      0.95     91.58 138012049
#
#      SF       0.95      0.43      0.80      0.56      4.07   6129754
#
#    mean       0.92      0.55      0.71      0.61    100.00 150694378
#
# overall       0.91      0.93      0.89      0.91    100.00 150694378
