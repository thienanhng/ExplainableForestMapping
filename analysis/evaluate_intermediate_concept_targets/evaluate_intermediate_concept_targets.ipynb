# %% [markdown]
# # Evaluate intermediate concept targets
# Here we apply the rules of the rule model of the SB model on the intermediate targets and compare the obtained segmentation with the TLM labels

# %%
# %matplotlib inline
import sys
import os

project_dir = os.path.dirname(os.path.dirname(os.getcwd()))
sys.path.append(project_dir)
import torch

from utils.viz_utils import *

# %%
class_names = (['NF', 'OF', 'CF', 'SF'], ['NF', 'F'], ['OF', 'CF', 'SF'])

def display_results(metrics_fn):
    d = torch.load(metrics_fn)
    cms = d['cms']
    reports = d['reports']
    for key, cn in zip(cms.keys(), class_names):
        print(cn)
        display_norm_cm(cms[key], class_names=cn)
        print_report(reports[key])

# %%
metrics_fn = os.path.join(project_dir, 'output/rules_on_regr_labels_TH_TCD1/test/metrics.pt')
display_results(metrics_fn)
# Out:
# ['NF', 'OF', 'CF', 'SF']
# IoU NF: 0.9358313083648682
# IoU OF: 0.09142749011516571
# IoU CF: 0.8877426981925964
# IoU SF: 0.5095041990280151
# mIoU: 0.6061264239251614
#           accuracy precision    recall  f1-score support (%)   support
#
#      NF       0.95      0.97      0.97      0.97     74.82 470062713
#
#      OF       0.95      0.10      0.44      0.17      1.03   6476643
#
#      CF       0.97      1.00      0.89      0.94     22.62 142089429
#
#      SF       0.99      1.00      0.51      0.68      1.53   9609568
#
#    mean       0.97      0.77      0.70      0.69    100.00 628238353
#
# overall       0.96      0.97      0.94      0.95    100.00 628238353
#
#
# ['NF', 'F']
# IoU NF: 0.9079045653343201
# IoU F: 0.7668570876121521
# mIoU: 0.8373808264732361
#           accuracy precision    recall  f1-score support (%)   support
#
#      NF       0.93      0.97      0.94      0.95     74.34 484800696
#
#       F       0.93      0.83      0.91      0.87     25.66 167319627
#
#    mean       0.93      0.90      0.92      0.91    100.00 652120323
#
# overall       0.93      0.93      0.93      0.93    100.00 652120323
#
#
# ['OF', 'CF', 'SF']
# IoU OF: 0.23394282162189484
# IoU CF: 0.9139699339866638
# IoU SF: 0.4497220516204834
# mIoU: 0.532544935743014
#           accuracy precision    recall  f1-score support (%)   support
#
#      OF       0.94      0.24      0.86      0.38      2.23   3283709
#
#      CF       0.92      1.00      0.91      0.96     93.61 138012049
#
#      SF       0.96      0.51      0.80      0.62      4.16   6129754
#
#    mean       0.94      0.58      0.86      0.65    100.00 147425512
#
# overall       0.92      0.96      0.91      0.93    100.00 147425512
